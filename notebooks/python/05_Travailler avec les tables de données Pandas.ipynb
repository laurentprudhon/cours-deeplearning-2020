# %% [markdown]
# ## Charger et mettre en forme une DataFrame
#
# On charge habituellement les données d'une DataFrame à partir d'un fichier externe, puis on réduit son contenu aux lignes et colonnes qui nous intéressent pour le traitement à suivre.
#
# Pandas supporte de nombreux format de fichiers : CSV, Excel, tables Html, base de données relationnelle.

# %% [markdown]
# On peut afficher le contenu d'un fichier dans un notebook Jupyter de la manière suivante :
# - commencer la ligne par un point d'exclamation
# - dans ce cas, le reste de la ligne est directement envoyé à la ligne de commande du système d'exploitation
# - utiliser la commande cat sous Unix ou la commande type sous Windows, suivie du nom de fichier

# %%
# !type annonces_immo.csv
# Out:
# crawlSource,url,marketingType,department,departmentCode,adCount
# LOGIC_IMMO,,SALE,NOUVELLE_CALEDONIE,988,0
# OUEST_FRANCE_IMMO,,SALE,LOT,46,0
# OUEST_FRANCE_IMMO,,SALE,HAUTES_PYRENEES,65,0
# OUEST_FRANCE_IMMO,,SALE,PARIS,75,0
# OUEST_FRANCE_IMMO,,SALE,TARN,81,0
# OUEST_FRANCE_IMMO,,SALE,SEINE_ET_MARNE,77,0
# OUEST_FRANCE_IMMO,,SALE,TARN_ET_GARONNE,82,0
# OUEST_FRANCE_IMMO,,SALE,YVELINES,78,0
# OUEST_FRANCE_IMMO,,SALE,AUDE,11,0
# OUEST_FRANCE_IMMO,,SALE,ESSONE,91,0
# OUEST_FRANCE_IMMO,,SALE,GARD,30,0
# OUEST_FRANCE_IMMO,,SALE,HAUTS_DE_SEINE,92,0
# OUEST_FRANCE_IMMO,,SALE,HERAULT,34,0
# OUEST_FRANCE_IMMO,,SALE,SEINE_SAINT_DENIS,93,0
# OUEST_FRANCE_IMMO,,SALE,LOZERE,48,0
# OUEST_FRANCE_IMMO,,SALE,VAL_DE_MARNE,94,0
# OUEST_FRANCE_IMMO,,SALE,PYRENEES_ORIENTALES,66,0
# OUEST_FRANCE_IMMO,,SALE,VAL_D_OISE,95,0
# OUEST_FRANCE_IMMO,,SALE,ALLIER,3,0
# OUEST_FRANCE_IMMO,,SALE,ALPES_DE_HAUTE_PROVENCE,4,0
# OUEST_FRANCE_IMMO,,SALE,CANTAL,15,0
# OUEST_FRANCE_IMMO,,SALE,HAUTES_ALPES,5,0
# OUEST_FRANCE_IMMO,,SALE,HAUTE_LOIRE,43,0
# OUEST_FRANCE_IMMO,,SALE,ALPES_MARITIMES,6,0
# OUEST_FRANCE_IMMO,,SALE,BOUCHE_DU_RHONE,13,0
# OUEST_FRANCE_IMMO,,SALE,PUY_DE_DOME,63,0
# OUEST_FRANCE_IMMO,,SALE,VAR,83,0
# OUEST_FRANCE_IMMO,,SALE,ARDENNES,8,0
# OUEST_FRANCE_IMMO,,SALE,VAUCLUSE,84,0
# OUEST_FRANCE_IMMO,,SALE,AUBE,10,0
# OUEST_FRANCE_IMMO,,SALE,DORDOGNE,24,0
# OUEST_FRANCE_IMMO,,SALE,MARNE,51,0
# OUEST_FRANCE_IMMO,,SALE,GIRONDE,33,0
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-VAL+D+OISE.php?sort=price_desc,SALE,VAL_D_OISE,95,0
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-60&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,OISE,60,5129
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-7&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,ARDECHE,7,2182
# OUEST_FRANCE_IMMO,,SALE,HAUTE_MARNE,52,0
# OUEST_FRANCE_IMMO,,SALE,LANDES,40,0
# OUEST_FRANCE_IMMO,,SALE,AISNE,2,0
# OUEST_FRANCE_IMMO,,SALE,LOT_ET_GARONNE,47,0
# OUEST_FRANCE_IMMO,,SALE,OISE,60,0
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-orne-61-u18d38061p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,ORNE,61,1792
# OUEST_FRANCE_IMMO,,SALE,PYRENEES_ATLANTIQUES,64,0
# OUEST_FRANCE_IMMO,,SALE,SOMME,80,0
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/limousin/correze?ret=1&ret=2&o=1&f=c,SALE,CORREZE,19,3211
# OUEST_FRANCE_IMMO,,SALE,AIN,1,0
# OUEST_FRANCE_IMMO,,SALE,NORD,59,0
# OUEST_FRANCE_IMMO,,SALE,ARDECHE,7,0
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-ALPES+DE+HAUTE+PROVENCE.php?sort=price_desc,SALE,ALPES_DE_HAUTE_PROVENCE,4,108
# OUEST_FRANCE_IMMO,,SALE,PAS_DE_CALAIS,62,0
# OUEST_FRANCE_IMMO,,SALE,DROME,26,0
# OUEST_FRANCE_IMMO,,SALE,CORREZE,19,0
# OUEST_FRANCE_IMMO,,SALE,CREUSE,23,0
# OUEST_FRANCE_IMMO,,SALE,HAUTE_VIENNE,87,0
# OUEST_FRANCE_IMMO,,SALE,ISERE,38,0
# OUEST_FRANCE_IMMO,,SALE,DOUBS,25,0
# OUEST_FRANCE_IMMO,,SALE,LOIRE,42,0
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-80&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,SOMME,80,3468
# OUEST_FRANCE_IMMO,,SALE,JURA,39,0
# OUEST_FRANCE_IMMO,,SALE,RHONE,69,0
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-26&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,DROME,26,3613
# OUEST_FRANCE_IMMO,,SALE,HAUTE_SAONE,70,0
# OUEST_FRANCE_IMMO,,SALE,SAVOIE,73,0
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/967/pt/1,2/",SALE,SEINE_ET_MARNE,77,21536
# OUEST_FRANCE_IMMO,,SALE,TERRITOIRE_DE_BELFORT,90,0
# OUEST_FRANCE_IMMO,,SALE,HAUTE_SAVOIE,74,0
# OUEST_FRANCE_IMMO,,SALE,ARIEGE,9,0
# OUEST_FRANCE_IMMO,,SALE,AVEYRON,12,0
# OUEST_FRANCE_IMMO,,SALE,HAUTE_GARONNE,31,0
# OUEST_FRANCE_IMMO,,SALE,GERS,32,0
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-HAUTES+ALPES.php?sort=price_desc,SALE,HAUTES_ALPES,5,34
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-59&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,NORD,59,12766
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-38&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,ISERE,38,4340
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-62&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,PAS_DE_CALAIS,62,7868
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-cote-d-or-21-u18d38021p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,COTE_D_OR,21,2802
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/limousin/creuse?ret=1&ret=2&o=1&f=c,SALE,CREUSE,23,841
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-ALPES+MARITIMES.php?sort=price_desc,SALE,ALPES_MARITIMES,6,8869
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/389/pt/1,2/",SALE,YVELINES,78,14515
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-42&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,LOIRE,42,2811
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2278%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,YVELINES,78,2575
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-19&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,CORREZE,19,4508
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-bouches+du+rhone.php?sort=price_desc,SALE,BOUCHE_DU_RHONE,13,2293
# OUEST_FRANCE_IMMO,http://www.ouestfrance-immo.com/acheter/?types=appartement%2Cmaison%2Cmeublee&lieux=522&page=1,SALE,COTES_D_ARMOR,22,12803
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-23&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,CREUSE,23,919
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-VAR.php?sort=price_desc,SALE,VAR,83,4608
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-69&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,RHONE,69,4550
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-nievre-58-u18d38058p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,NIEVRE,58,1136
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/1662/pt/1,2/",SALE,ESSONE,91,17274
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-73&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,SAVOIE,73,2404
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/limousin/haute_vienne?ret=1&ret=2&o=1&f=c,SALE,HAUTE_VIENNE,87,3840
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-VAUCLUSE.php?sort=price_desc,SALE,VAUCLUSE,84,1389
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2291%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,ESSONE,91,2927
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-87&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,HAUTE_VIENNE,87,2868
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-25&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,DOUBS,25,1887
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-74&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,HAUTE_SAVOIE,74,5584
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-DORDOGNE.php?sort=price_desc,SALE,DORDOGNE,24,217
# OUEST_FRANCE_IMMO,http://www.ouestfrance-immo.com/acheter/?types=appartement%2Cmaison%2Cmeublee&lieux=529&page=1,SALE,FINISTERE,29,10034
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/25/pt/1,2/",SALE,HAUTS_DE_SEINE,92,6636
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-9&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,ARIEGE,9,2287
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-GIRONDE.php?sort=price_desc,SALE,GIRONDE,33,744
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-39&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,JURA,39,1139
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-LANDES.php?sort=price_desc,SALE,LANDES,40,110
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/franche_comte/doubs?ret=1&ret=2&o=1&f=c,SALE,DOUBS,25,4597
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2292%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,HAUTS_DE_SEINE,92,1334
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-12&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,AVEYRON,12,1839
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-70&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,HAUTE_SAONE,70,932
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-LOT+ET+GARONNE.php?sort=price_desc,SALE,LOT_ET_GARONNE,47,121
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-31&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,HAUTE_GARONNE,31,9261
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/215/pt/1,2/",SALE,SEINE_SAINT_DENIS,93,9757
# OUEST_FRANCE_IMMO,http://www.ouestfrance-immo.com/acheter/?types=appartement%2Cmaison%2Cmeublee&lieux=535%2C15818&page=1,SALE,ILLE_ET_VILAINE,35,16649
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-90&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,TERRITOIRE_DE_BELFORT,90,574
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2293%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,SEINE_SAINT_DENIS,93,1866
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/franche_comte/jura?ret=1&ret=2&o=1&f=c,SALE,JURA,39,2951
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-32&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,GERS,32,2634
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-PYRENEES+ATLANTIQUES.php?sort=price_desc,SALE,PYRENEES_ATLANTIQUES,64,379
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-22&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,COTES_D_ARMOR,22,4436
# SE_LOGER,http://www.seloger.com/list.htm?cp=32&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,GERS,32,2433
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-46&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,LOT,46,2353
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-29&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,FINISTERE,29,6823
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2294%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,VAL_DE_MARNE,94,1701
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/767/pt/1,2/",SALE,VAL_DE_MARNE,94,8579
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-AIN.php?sort=price_desc,SALE,AIN,1,91
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-35&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,ILLE_ET_VILAINE,35,3755
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-65&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,HAUTES_PYRENEES,65,2415
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/franche_comte/haute_saone?ret=1&ret=2&o=1&f=c,SALE,HAUTE_SAONE,70,1945
# SE_LOGER,http://www.seloger.com/list.htm?cp=46&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,LOT,46,2080
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-ARDECHE.php?sort=price_desc,SALE,ARDECHE,7,55
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-56&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,MORBIHAN,56,5409
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-81&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,TARN,81,4960
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2295%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,VAL_D_OISE,95,1821
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/1935/pt/1,2/",SALE,VAL_D_OISE,95,13053
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-44&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,LOIRE_ATLANTIQUE,44,8100
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-DROME.php?sort=price_desc,SALE,DROME,26,234
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-82&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,TARN_ET_GARONNE,82,2390
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-ISERE.php?sort=price_desc,SALE,ISERE,38,58
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-49&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,MAINE_ET_LOIRE,49,4482
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-eure-et-loir-28,53_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,EURE_ET_LOIRE,28,5255
# SE_LOGER,http://www.seloger.com/list.htm?cp=65&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,HAUTES_PYRENEES,65,2231
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2204%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,ALPES_DE_HAUTE_PROVENCE,4,1043
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/franche_comte/territoire_de_belfort?ret=1&ret=2&o=1&f=c,SALE,TERRITOIRE_DE_BELFORT,90,1535
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/7976/pt/1,2/",SALE,ALPES_DE_HAUTE_PROVENCE,4,3159
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-LOIRE.php?sort=price_desc,SALE,LOIRE,42,29
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-53&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,MAYENNE,53,1241
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-11&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,AUDE,11,5087
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-RHONE.php?sort=price_desc,SALE,RHONE,69,244
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-indre-36,61_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,INDRE,36,1923
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-30&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,GARD,30,7436
# SE_LOGER,http://www.seloger.com/list.htm?cp=81&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,TARN,81,3967
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-72&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,SARTHE,72,3082
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2205%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,HAUTES_ALPES,5,979
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-SAVOIE.php?sort=price_desc,SALE,SAVOIE,73,406
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/bretagne/cotes_d_armor?ret=1&ret=2&o=1&f=c,SALE,COTES_D_ARMOR,22,8783
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/8361/pt/1,2/",SALE,HAUTES_ALPES,5,1136
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-34&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,HERAULT,34,15047
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-HAUTE+SAVOIE.php?sort=price_desc,SALE,HAUTE_SAVOIE,74,1157
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-85&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,VENDEE,85,10221
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-48&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,LOZERE,48,381
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-16&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,CHARENTE,16,4388
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-ARIEGE.php?sort=price_desc,SALE,ARIEGE,9,11
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-indre-et-loire-37,62_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,INDRE_ET_LOIRE,37,5093
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/bretagne/finistere?ret=1&ret=2&o=1&f=c,SALE,FINISTERE,29,12278
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/7130/pt/1,2/",SALE,ALPES_MARITIMES,6,34809
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-17&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,CHARENTE_MARITIME,17,12420
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-66&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,PYRENEES_ORIENTALES,66,8715
# SE_LOGER,http://www.seloger.com/list.htm?cp=82&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,TARN_ET_GARONNE,82,3028
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-AVEYRON.php?sort=price_desc,SALE,AVEYRON,12,29
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2206%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,ALPES_MARITIMES,6,12316
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-79&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,DEUX_SEVRES,79,5961
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-3&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,ALLIER,3,3380
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-HAUTE+GARONNE.php?sort=price_desc,SALE,HAUTE_GARONNE,31,174
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-86&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,VIENNE,86,3549
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-loir-et-cher-41,66_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,LOIR_ET_CHER,41,2725
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/6794/pt/1,2/",SALE,BOUCHE_DU_RHONE,13,18560
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-15&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,CANTAL,15,569
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/bretagne/ille_et_vilaine?ret=1&ret=2&o=1&f=c,SALE,ILLE_ET_VILAINE,35,13993
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-GERS.php?sort=price_desc,SALE,GERS,32,102
# SE_LOGER,http://www.seloger.com/list.htm?cp=11&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,AUDE,11,4309
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-43&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,HAUTE_LOIRE,43,827
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-18&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,CHER,18,2811
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-loiret-45,70_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,LOIRET,45,7735
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2213%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,BOUCHE_DU_RHONE,13,4691
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-LOT.php?sort=price_desc,SALE,LOT,46,41
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-saone-et-loire-71-u18d38071p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,SAONE_ET_LOIRE,71,4749
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-63&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,PUY_DE_DOME,63,1298
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-28&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,EURE_ET_LOIRE,28,4807
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/7467/pt/1,2/",SALE,VAR,83,33204
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/bretagne/morbihan?ret=1&ret=2&o=1&f=c,SALE,MORBIHAN,56,11346
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-HAUTES+PYRENEES.php?sort=price_desc,SALE,HAUTES_PYRENEES,65,20
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-36&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,INDRE,36,3299
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-8&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,ARDENNES,8,738
# SE_LOGER,http://www.seloger.com/list.htm?cp=30&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,GARD,30,12136
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-eure-27,52_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,EURE,27,6956
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-yonne-89-u18d38089p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,YONNE,89,1420
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-TARN.php?sort=price_desc,SALE,TARN,81,103
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-10&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,AUBE,10,1741
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2283%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,VAR,83,12555
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-37&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,INDRE_ET_LOIRE,37,5577
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-TARN+ET+GARONNE.php?sort=price_desc,SALE,TARN_ET_GARONNE,82,67
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-seine-maritime-76,101_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,SEINE_MARITIME,76,13801
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-51&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,MARNE,51,1573
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/pays_de_la_loire/loire_atlantique?ret=1&ret=2&o=1&f=c,SALE,LOIRE_ATLANTIQUE,44,17605
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/7759/pt/1,2/",SALE,VAUCLUSE,84,10208
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-41&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,LOIR_ET_CHER,41,4038
# SE_LOGER,http://www.seloger.com/list.htm?cp=34&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,HERAULT,34,22591
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-bas-rhin-67-u18d38067p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,BAS_RHIN,67,986
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-52&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,HAUTE_MARNE,52,767
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-AUDE.php?sort=price_desc,SALE,AUDE,11,166
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2284%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,VAUCLUSE,84,1831
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-45&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,LOIRET,45,6425
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-calvados-14,36_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,CALVADOS,14,9873
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-GARD.php?sort=price_desc,SALE,GARD,30,604
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-2&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,AISNE,2,3309
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-27&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,EURE,27,7604
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/pays_de_la_loire/maine_et_loire?ret=1&ret=2&o=1&f=c,SALE,MAINE_ET_LOIRE,49,10465
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-HERAULT.php?sort=price_desc,SALE,HERAULT,34,754
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-60&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,OISE,60,3916
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2224%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,DORDOGNE,24,4690
# SE_LOGER,http://www.seloger.com/list.htm?cp=48&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,LOZERE,48,252
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-manche-50,75_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,MANCHE,50,3595
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/pays_de_la_loire/mayenne?ret=1&ret=2&o=1&f=c,SALE,MAYENNE,53,3793
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-haut-rhin-68-u18d38068p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,HAUT_RHIN,68,905
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-76&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,SEINE_MARITIME,76,7030
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-80&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,SOMME,80,3036
# LUX_RESIDENCE,http://www.lux-residence.com/fr/annonces/vente/immobilier-prestige-LOZERE.php?sort=price_desc,SALE,LOZERE,48,6
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-47&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,LOT_ET_GARONNE,47,5455
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-59&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,NORD,59,11448
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/14437/pt/1,2/",SALE,DORDOGNE,24,6464
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-manche-basse+normandie-france/,SALE,MANCHE,50,53
# SE_LOGER,http://www.seloger.com/list.htm?cp=66&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,PYRENEES_ORIENTALES,66,7561
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-64&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,PYRENEES_ATLANTIQUES,64,5115
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-62&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,PAS_DE_CALAIS,62,7290
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2233%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,GIRONDE,33,6408
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-orne-61,86_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,ORNE,61,1899
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-meurthe-et-moselle-54-u18d38054p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,MEURTHE_ET_MOSELLE,54,1473
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-1&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,AIN,1,2533
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/pays_de_la_loire/sarthe?ret=1&ret=2&o=1&f=c,SALE,SARTHE,72,6941
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-19&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,CORREZE,19,4113
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/13010/pt/1,2/",SALE,GIRONDE,33,17154
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-cote-d-or-21,46_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,COTE_D_OR,21,3360
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-7&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,ARDECHE,7,2492
# SE_LOGER,http://www.seloger.com/list.htm?cp=03&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,ALLIER,3,2170
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/pays_de_la_loire/vendee?ret=1&ret=2&o=1&f=c,SALE,VENDEE,85,11605
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2240%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,LANDES,40,3273
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-26&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,DROME,26,4193
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-23&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,CREUSE,23,889
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-meuse-55-u18d38055p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,MEUSE,55,974
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-nievre-58,83_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,NIEVRE,58,505
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/poitou_charentes/charente?ret=1&ret=2&o=1&f=c,SALE,CHARENTE,16,4153
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-38&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,ISERE,38,4531
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-87&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,HAUTE_VIENNE,87,2535
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-saone-et-loire-71,96_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,SAONE_ET_LOIRE,71,3186
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/15217/pt/1,2/",SALE,LANDES,40,5278
# SE_LOGER,http://www.seloger.com/list.htm?cp=15&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,CANTAL,15,489
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2247%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,LOT_ET_GARONNE,47,3118
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-42&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,LOIRE,42,3146
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/poitou_charentes/charente_maritime?ret=1&ret=2&o=1&f=c,SALE,CHARENTE_MARITIME,17,12645
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-moselle-57-u18d38057p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,MOSELLE,57,1533
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-25&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,DOUBS,25,1757
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-yonne-89,114_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,YONNE,89,2118
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-69&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,RHONE,69,4996
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-73&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,SAVOIE,73,2780
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-39&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,JURA,39,1129
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-bas-rhin-67,92_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,BAS_RHIN,67,6867
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/15608/pt/1,2/",SALE,LOT_ET_GARONNE,47,4764
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2264%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,PYRENEES_ATLANTIQUES,64,3407
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-70&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,HAUTE_SAONE,70,923
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-vosges-88-u18d38088p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,VOSGES,88,588
# SE_LOGER,http://www.seloger.com/list.htm?cp=43&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,HAUTE_LOIRE,43,849
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-haut-rhin-68,93_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,HAUT_RHIN,68,5573
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-90&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,TERRITOIRE_DE_BELFORT,90,609
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-orne-basse+normandie-france/,SALE,ORNE,61,64
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2201%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,AIN,1,543
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-22&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,COTES_D_ARMOR,22,3746
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-corse-du-sud-2a-u18d380201p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,CORSE_DU_SUD,2A,825
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/13726/pt/1,2/",SALE,PYRENEES_ATLANTIQUES,64,7716
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-meurthe-et-moselle-54,79_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,MEURTHE_ET_MOSELLE,54,5339
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-29&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,FINISTERE,29,6375
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-35&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,ILLE_ET_VILAINE,35,3587
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-74&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,HAUTE_SAVOIE,74,6083
# TOP_ANNONCES,http://www.topannonces.fr/annonces-vente-immobilier-haute-corse-2b-u18d38202p1.html?FlatCriterias=P_OBJ_GEOLOC%4097%3Dgclt%3B48%2C856614%3B2%2C352222%3B0,SALE,HAUTE_CORSE,2B,895
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2207%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,ARDECHE,7,411
# TOP_ANNONCES,,SALE,GUADELOUPE,971,0
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-56&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,MORBIHAN,56,4517
# TOP_ANNONCES,,SALE,MARTINIQUE,972,0
# SE_LOGER,http://www.seloger.com/list.htm?cp=63&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,PUY_DE_DOME,63,2298
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-9&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,ARIEGE,9,2298
# TOP_ANNONCES,,SALE,GUYANE,973,0
# TOP_ANNONCES,,SALE,ILE_DE_LA_REUNION,974,0
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-meuse-55,80_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,MEUSE,55,822
# TOP_ANNONCES,,SALE,SAINT_PIERRE_ET_MIQUELON,975,0
# TOP_ANNONCES,,SALE,MAYOTTE,976,0
# TOP_ANNONCES,,SALE,SAINT_BARTHELEMY_ANTILLES,977,0
# TOP_ANNONCES,,SALE,ILE_DE_SAINT_MARTIN_ANTILLES,978,0
# TOP_ANNONCES,,SALE,WALLIS_ET_FUTUNA,986,0
# TOP_ANNONCES,,SALE,POLYNESIE_FRANCAISE,987,0
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-44&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,LOIRE_ATLANTIQUE,44,6772
# TOP_ANNONCES,,SALE,NOUVELLE_CALEDONIE,988,0
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-12&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,AVEYRON,12,1890
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/4570/pt/1,2/",SALE,AIN,1,4653
# IMMONOT,http://www.immonot.com/immobilier.do?action=recherche&transactions=VENT&localite=75&typesBiens=MAIS&typesBiens=APPT&indexDebut=0,SALE,PARIS,75,35
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2226%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,DROME,26,2601
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-49&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,MAINE_ET_LOIRE,49,3130
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-moselle-57,82_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,MOSELLE,57,5019
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-31&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,HAUTE_GARONNE,31,9541
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-53&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,MAYENNE,53,1172
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-32&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,GERS,32,2766
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-vosges-88,113_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,VOSGES,88,1486
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-72&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,SARTHE,72,2475
# SE_LOGER,http://www.seloger.com/list.htm?cp=08&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,ARDENNES,8,668
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-46&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,LOT,46,2485
# IMMONOT,http://www.immonot.com/immobilier.do?action=recherche&transactions=VENT&localite=77&typesBiens=MAIS&typesBiens=APPT&indexDebut=0,SALE,SEINE_ET_MARNE,77,79
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-85&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,VENDEE,85,7987
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-corse-du-sud-2a,42_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,CORSE_DU_SUD,2A,1047
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2238%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,ISERE,38,2148
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/poitou_charentes/deux_sevres?ret=1&ret=2&o=1&f=c,SALE,DEUX_SEVRES,79,5348
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-16&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,CHARENTE,16,4105
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/6283/pt/1,2/",SALE,ARDECHE,7,2483
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-haute-corse-2b,44_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,HAUTE_CORSE,2B,624
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-17&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,CHARENTE_MARITIME,17,10474
# IMMONOT,http://www.immonot.com/immobilier.do?action=recherche&transactions=VENT&localite=78&typesBiens=MAIS&typesBiens=APPT&indexDebut=0,SALE,YVELINES,78,6
# SE_LOGER,http://www.seloger.com/list.htm?cp=10&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,AUBE,10,2150
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2242%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,LOIRE,42,2418
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/poitou_charentes/vienne?ret=1&ret=2&o=1&f=c,SALE,VIENNE,86,4982
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-79&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,DEUX_SEVRES,79,4820
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-cote+d+or-bourgogne-france/,SALE,COTE_D_OR,21,112
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-guadeloupe-971,40266_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,GUADELOUPE,971,392
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-86&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,VIENNE,86,3208
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-18&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,CHER,18,2460
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2269%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,RHONE,69,2622
# IMMONOT,http://www.immonot.com/immobilier.do?action=recherche&transactions=VENT&localite=91&typesBiens=MAIS&typesBiens=APPT&indexDebut=0,SALE,ESSONE,91,18
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-martinique-972,40269_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,MARTINIQUE,972,231
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/centre/cher?ret=1&ret=2&o=1&f=c,SALE,CHER,18,3372
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-28&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,EURE_ET_LOIRE,28,4091
# SE_LOGER,http://www.seloger.com/list.htm?cp=51&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,MARNE,51,3238
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-guyane-973,40267_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,GUYANE,973,311
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/5202/pt/1,2/",SALE,DROME,26,5020
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-36&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,INDRE,36,3052
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/centre/eure_et_loir?ret=1&ret=2&o=1&f=c,SALE,EURE_ET_LOIRE,28,6177
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2273%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,SAVOIE,73,506
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-37&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,INDRE_ET_LOIRE,37,4796
# IMMONOT,http://www.immonot.com/immobilier.do?action=recherche&transactions=VENT&localite=92&typesBiens=MAIS&typesBiens=APPT&indexDebut=0,SALE,HAUTS_DE_SEINE,92,12
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-la-reunion-974,40270_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,ILE_DE_LA_REUNION,974,810
# LOGIC_IMMO,,SALE,SAINT_PIERRE_ET_MIQUELON,975,0
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-41&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,LOIR_ET_CHER,41,3711
# LOGIC_IMMO,,SALE,MAYOTTE,976,0
# LOGIC_IMMO,,SALE,SAINT_BARTHELEMY_ANTILLES,977,0
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2274%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,HAUTE_SAVOIE,74,4760
# LOGIC_IMMO,,SALE,ILE_DE_SAINT_MARTIN_ANTILLES,978,0
# LOGIC_IMMO,,SALE,WALLIS_ET_FUTUNA,986,0
# SE_LOGER,http://www.seloger.com/list.htm?cp=52&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,HAUTE_MARNE,52,579
# LOGIC_IMMO,,SALE,POLYNESIE_FRANCAISE,987,0
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/centre/indre?ret=1&ret=2&o=1&f=c,SALE,INDRE,36,2566
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-65&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,HAUTES_PYRENEES,65,2547
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-45&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,LOIRET,45,5394
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-haute-loire-43,68_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,HAUTE_LOIRE,43,1214
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-27&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,EURE,27,6496
# IMMONOT,http://www.immonot.com/immobilier.do?action=recherche&transactions=VENT&localite=93&typesBiens=MAIS&typesBiens=APPT&indexDebut=0,SALE,SEINE_SAINT_DENIS,93,4
# LE_BON_COIN,http://www.leboncoin.fr/ventes_immobilieres/offres/centre/indre_et_loire?ret=1&ret=2&o=1&f=c,SALE,INDRE_ET_LOIRE,37,8464
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-81&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,TARN,81,5115
# LOGIC_IMMO,"http://www.logic-immo.com/vente-immobilier-puy-de-dome-63,88_1/options/groupprptypesids=1,2,6,7,8,9,12,13/page=1/order=update_date_desc",SALE,PUY_DE_DOME,63,6460
# FNAIM,http://www.fnaim.fr/17-acheter.htm?localites=%5B%7B%22id%22%3A%2209%22%2C%22type%22%3A%222%22%7D%5D&TYPE%5B%5D=1&TYPE%5B%5D=2,SALE,ARIEGE,9,66
# SE_LOGER,http://www.seloger.com/list.htm?cp=02&idtt=2&naturebien=1%2C3&idtypebien=1%2C2%2C9%2C13%2C14,SALE,AISNE,2,4119
# ANNONCES_JAUNES,http://www.annoncesjaunes.fr/recherche.html?searchTypeID=1&localityIds=3-76&transactionId=1&typeGroupIds=1%2C2%2C23%2C24%2C25&pageIndex=1,SALE,SEINE_MARITIME,76,6496
# A_VENDRE_A_LOUER,http://www.avendrealouer.fr/recherche.html?pageIndex=1&localityIds=3-82&searchTypeID=1&typeGroupCategoryID=1&typeGroupIds=1%2C2%2C10%2C11%2C12,SALE,TARN_ET_GARONNE,82,2399
# SUPER_IMMO,"http://www.superimmo.com/rechercher/achat/l/2629/pt/1,2/",SALE,ISERE,38,10895
# ...
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=975&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,SAINT_PIERRE_ET_MIQUELON,975,1
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-lozere-languedoc+roussillon-france/,SALE,LOZERE,48,14
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=15&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,CANTAL,15,14
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=53&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,MAYENNE,53,15
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-mayenne-pays+de+loire-france/,SALE,MAYENNE,53,38
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-pyrenees+orientales-languedoc+roussillon-france/,SALE,PYRENEES_ORIENTALES,66,164
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=47&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,LOT_ET_GARONNE,47,111
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-sarthe-pays+de+loire-france/,SALE,SARTHE,72,67
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=976&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,MAYOTTE,976,0
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-allier-auvergne-france/,SALE,ALLIER,3,86
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=43&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,HAUTE_LOIRE,43,6
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=72&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,SARTHE,72,61
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-vendee-pays+de+loire-france/,SALE,VENDEE,85,91
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-cantal-auvergne-france/,SALE,CANTAL,15,16
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=64&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,PYRENEES_ATLANTIQUES,64,303
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-charente-poitou+charentes-france/,SALE,CHARENTE,16,107
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=977&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,SAINT_BARTHELEMY_ANTILLES,977,8
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-haute+loire-auvergne-france/,SALE,HAUTE_LOIRE,43,13
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=63&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,PUY_DE_DOME,63,47
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=85&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,VENDEE,85,90
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-charente+maritime-poitou+charentes-france/,SALE,CHARENTE_MARITIME,17,326
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-puy+de+dome-auvergne-france/,SALE,PUY_DE_DOME,63,92
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=01&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,AIN,1,116
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-deux+sevres-poitou+charentes-france/,SALE,DEUX_SEVRES,79,154
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=978&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,ILE_DE_SAINT_MARTIN_ANTILLES,978,10
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-ardennes-champagne+ardenne-france/,SALE,ARDENNES,8,4
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=08&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,ARDENNES,8,3
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=16&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,CHARENTE,16,138
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-vienne-poitou+charentes-france/,SALE,VIENNE,86,122
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-aube-champagne+ardenne-france/,SALE,AUBE,10,18
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=07&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,ARDECHE,7,18
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-cher-centre-france/,SALE,CHER,18,52
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=986&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,WALLIS_ET_FUTUNA,986,0
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-marne-champagne+ardenne-france/,SALE,MARNE,51,29
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=10&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,AUBE,10,13
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=17&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,CHARENTE_MARITIME,17,311
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-eure+et+loir-centre-france/,SALE,EURE_ET_LOIRE,28,27
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-haute+marne-champagne+ardenne-france/,SALE,HAUTE_MARNE,52,14
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=26&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,DROME,26,61
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-indre-centre-france/,SALE,INDRE,36,29
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=987&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,POLYNESIE_FRANCAISE,987,0
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-aisne-picardie-france/,SALE,AISNE,2,28
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=51&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,MARNE,51,26
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=79&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,DEUX_SEVRES,79,59
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-indre+et+loire-centre-france/,SALE,INDRE_ET_LOIRE,37,144
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-oise-picardie-france/,SALE,OISE,60,85
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=38&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,ISERE,38,93
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-loir+et+cher-centre-france/,SALE,LOIR_ET_CHER,41,84
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=988&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,NOUVELLE_CALEDONIE,988,0
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=52&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,HAUTE_MARNE,52,10
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-loiret-centre-france/,SALE,LOIRET,45,76
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=86&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,VIENNE,86,74
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-eure-haute+normandie-france/,SALE,EURE,27,141
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-paris-ile+de+france-france/,SALE,PARIS,75,1869
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-seine+maritime-haute+normandie-france/,SALE,SEINE_MARITIME,76,58
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=42&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,LOIRE,42,25
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=02&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,AISNE,2,26
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=18&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,CHER,18,55
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-seine+et+marne-ile+de+france-france/,SALE,SEINE_ET_MARNE,77,126
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-calvados-basse+normandie-france/,SALE,CALVADOS,14,252
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=69&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,RHONE,69,407
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-yvelines-ile+de+france-france/,SALE,YVELINES,78,465
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=60&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,OISE,60,173
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=28&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,EURE_ET_LOIRE,28,46
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-essonne-ile+de+france-france/,SALE,ESSONE,91,34
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-hauts+de+seine-ile+de+france-france/,SALE,HAUTS_DE_SEINE,92,538
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=73&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,SAVOIE,73,77
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-seine+saint+denis-ile+de+france-france/,SALE,SEINE_SAINT_DENIS,93,24
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=80&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,SOMME,80,25
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=36&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,INDRE,36,15
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-val+de+marne-ile+de+france-france/,SALE,VAL_DE_MARNE,94,79
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-val+d+oise-ile+de+france-france/,SALE,VAL_D_OISE,95,78
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=74&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,HAUTE_SAVOIE,74,463
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-alpes+de+haute+provence-provence+alpes+cote+d+azur-france/,SALE,ALPES_DE_HAUTE_PROVENCE,4,39
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=59&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,NORD,59,85
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=37&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,INDRE_ET_LOIRE,37,199
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-hautes+alpes-provence+alpes+cote+d+azur-france/,SALE,HAUTES_ALPES,5,7
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-alpes+maritimes-provence+alpes+cote+d+azur-france/,SALE,ALPES_MARITIMES,6,2015
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=09&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,ARIEGE,9,27
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-bouches+du+rhone-provence+alpes+cote+d+azur-france/,SALE,BOUCHE_DU_RHONE,13,849
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=62&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,PAS_DE_CALAIS,62,59
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=41&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,LOIR_ET_CHER,41,75
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-var-provence+alpes+cote+d+azur-france/,SALE,VAR,83,1604
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-vaucluse-provence+alpes+cote+d+azur-france/,SALE,VAUCLUSE,84,673
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=12&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,AVEYRON,12,28
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-dordogne-aquitaine-france/,SALE,DORDOGNE,24,179
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=19&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,CORREZE,19,15
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=45&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,LOIRET,45,79
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-gironde-aquitaine-france/,SALE,GIRONDE,33,448
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-landes-aquitaine-france/,SALE,LANDES,40,105
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=23&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,CREUSE,23,5
# PROPRIETES_DE_FRANCE,http://proprietes.lefigaro.fr/annonces/immobilier-lot+et+garonne-aquitaine-france/,SALE,LOT_ET_GARONNE,47,114
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=27&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,EURE,27,166
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=87&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,HAUTE_VIENNE,87,18
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=76&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,SEINE_MARITIME,76,88
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=25&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,DOUBS,25,6
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=14&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,CALVADOS,14,327
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=39&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,JURA,39,9
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=50&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,MANCHE,50,42
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=70&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,HAUTE_SAONE,70,5
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=61&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,ORNE,61,79
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=90&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,TERRITOIRE_DE_BELFORT,90,2
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=21&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,COTE_D_OR,21,71
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=22&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,COTES_D_ARMOR,22,133
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=58&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,NIEVRE,58,29
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=71&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,SAONE_ET_LOIRE,71,66
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=89&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,YONNE,89,72
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=67&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,BAS_RHIN,67,11
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=68&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,HAUT_RHIN,68,7
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=54&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,MEURTHE_ET_MOSELLE,54,4
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=55&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,MEUSE,55,1
# BELLES_DEMEURES,http://www.bellesdemeures.com/recherche.htm?cp=57&idtt=8&idtypebien=1%2C13%2C14%2C2%2C2.27%2C2.28%2C2.52%2C2.66%2C9,SALE,MOSELLE,57,1

# %%
import pandas as pd
df = pd.read_csv("annonces_immo.csv")
df.head()
# Out:
#          crawlSource  url marketingType          department departmentCode  \
# 0         LOGIC_IMMO  NaN          SALE  NOUVELLE_CALEDONIE            988
# 1  OUEST_FRANCE_IMMO  NaN          SALE                 LOT             46
# 2  OUEST_FRANCE_IMMO  NaN          SALE     HAUTES_PYRENEES             65
# 3  OUEST_FRANCE_IMMO  NaN          SALE               PARIS             75
# 4  OUEST_FRANCE_IMMO  NaN          SALE                TARN             81
#
#    adCount
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# Le paramètre **skiprows** permet d'indiquer la ligne du fichier sur laquelle se trouvent les noms de colonnes.
#
# Le paramètre **index_col** permet d'indiquer l'indice de la colonne du fichier à utiliser comme index (à défaut, des index numériques sont créés automatiquement, comme vu ci-dessus).

# %%
df = pd.read_csv("annonces_immo.csv", index_col=3)
df.head()
# Out:
#                           crawlSource  url marketingType departmentCode  \
# department
# NOUVELLE_CALEDONIE         LOGIC_IMMO  NaN          SALE            988
# LOT                 OUEST_FRANCE_IMMO  NaN          SALE             46
# HAUTES_PYRENEES     OUEST_FRANCE_IMMO  NaN          SALE             65
# PARIS               OUEST_FRANCE_IMMO  NaN          SALE             75
# TARN                OUEST_FRANCE_IMMO  NaN          SALE             81
#
#                     adCount
# department
# NOUVELLE_CALEDONIE        0
# LOT                       0
# HAUTES_PYRENEES           0
# PARIS                     0
# TARN                      0

# %% [markdown]
# On peut modifier le nom des colonnes pour rendre la table de données plus lisible à l'aide de la méthode **rename()** et supprimer les colonnes inutiles à l'aide de la méthode **drop()**.

# %%
df.rename(columns={"crawlSource":"site","adCount":"annonces"}, inplace=True)
df.drop(["url","marketingType","departmentCode"], axis=1, inplace=True)
df.head()
# Out:
#                                  site  annonces
# department
# NOUVELLE_CALEDONIE         LOGIC_IMMO         0
# LOT                 OUEST_FRANCE_IMMO         0
# HAUTES_PYRENEES     OUEST_FRANCE_IMMO         0
# PARIS               OUEST_FRANCE_IMMO         0
# TARN                OUEST_FRANCE_IMMO         0

# %% [markdown]
# ## Requêter une DataFrame
#
# La technique de **boolean masking** est au coeur du mécanisme d'exécution rapide de requêtes dans les librairies Numpy et Pandas.
#
# Un masque de booléens est une table à une dimensions comme une structure Series, ou une table à deux dimensions comme une structure DataFrame dans laquelle chaque valeur est vraie ou fausse.
#
# Cette table de sélection est superposée à la structure de données à requêter, pour décider des valeurs à conserver ou non dans le résultat retourné.
#
# Par exemple, pour filtrer les lignes qui ont un nombre d'annonces non nul, on commence par créer une table de valeurs vrai/faux à superposer à la colonne "annonces":

# %%
masque = df["annonces"] > 0
masque.head(10)
# Out:
# department
# NOUVELLE_CALEDONIE    False
# LOT                   False
# HAUTES_PYRENEES       False
# PARIS                 False
# TARN                  False
# SEINE_ET_MARNE        False
# TARN_ET_GARONNE       False
# YVELINES              False
# AUDE                  False
# ESSONE                False
# Name: annonces, dtype: bool

# %% [markdown]
# Dans l'instruction ci-dessus, l'opérateur de comparaison > 0 a été distribué (**broadcasting**) sur chacune des valeurs de la structure Series correspondant à la colonne à filter, construisant un objet Series qui contient des valeurs vrai ou faux.
#
# On applique ce masque de filtrage à la DataFrame à l'aide de la méthode **where()** :

# %%
filtre1 = df.where(df["annonces"] > 0)
filtre1.head()
# Out:
#                    site  annonces
# department
# NOUVELLE_CALEDONIE  NaN       NaN
# LOT                 NaN       NaN
# HAUTES_PYRENEES     NaN       NaN
# PARIS               NaN       NaN
# TARN                NaN       NaN

# %% [markdown]
# On voit que toutes les valeurs des lignes non sélectionnées ont été remplacées par NaN.
#
# Toutes les fonctions de calcul de statistiques sur les données de la DataFrame ignorent les valeurs NaN, le filtre est pris en compte :

# %%
print(df["annonces"].count())
print(filtre1["annonces"].count())
# Out:
# 1819
# 1608

# %% [markdown]
# On peut effectivement supprimer les lignes du tableau plutôt que les filtrer à l'aide de la méthode **dropna()**.

# %%
filtre2 = filtre1.dropna()
filtre2.head()
# Out:
#                                      site  annonces
# department
# OISE                     A_VENDRE_A_LOUER    5129.0
# ARDECHE                   ANNONCES_JAUNES    2182.0
# ORNE                         TOP_ANNONCES    1792.0
# CORREZE                       LE_BON_COIN    3211.0
# ALPES_DE_HAUTE_PROVENCE     LUX_RESIDENCE     108.0

# %% [markdown]
# On peut filtrer directement les lignes d'une DataFrame à l'aide de **l'opérateur d'indexation (crochets)**, qui peut aussi prendre en paramètre un masque booléen. NB : dans ce cas, aucune valeur NaN n'est retournée, les lignes exclues du filtre ne sont retirées du résultat.

# %%
filtre3 = df[df["annonces"] > 0]
filtre3.head()
# Out:
#                                      site  annonces
# department
# OISE                     A_VENDRE_A_LOUER      5129
# ARDECHE                   ANNONCES_JAUNES      2182
# ORNE                         TOP_ANNONCES      1792
# CORREZE                       LE_BON_COIN      3211
# ALPES_DE_HAUTE_PROVENCE     LUX_RESIDENCE       108

# %% [markdown]
# On peut chainer plusieurs masques booléens (*attention : obligatoirement definis entre parenthèses*) avec des opérateurs booléens **& (bitwise and)** et **| (bitwise or)** pour créer un masque booléen plus complexe :

# %%
filtre4 = df[(df["annonces"] > 0) & (df["site"] == "LE_BON_COIN")]
filtre4.head()
# Out:
#                      site  annonces
# department
# CORREZE       LE_BON_COIN      3211
# CREUSE        LE_BON_COIN       841
# HAUTE_VIENNE  LE_BON_COIN      3840
# DOUBS         LE_BON_COIN      4597
# JURA          LE_BON_COIN      2951

# %% [markdown]
# La fonction **unique()** permet de lister les valeurs distinctes d'une Series :

# %%
filtre3["site"].unique()
# Out:
# array(['A_VENDRE_A_LOUER', 'ANNONCES_JAUNES', 'TOP_ANNONCES',
#        'LE_BON_COIN', 'LUX_RESIDENCE', 'SUPER_IMMO', 'FNAIM',
#        'OUEST_FRANCE_IMMO', 'SE_LOGER', 'LOGIC_IMMO',
#        'PROPRIETES_DE_FRANCE', 'IMMONOT', 'ACHETER_LOUER', 'PARU_VENDU',
#        'EXPLORIMMO', 'BELLES_DEMEURES', 'BIEN_ICI'], dtype=object)

# %% [markdown]
# ## Définir l'index d'une DataFrame

# %% [markdown]
# La fonction **set_index()** prend en paramètre une liste de colonnes et les promeut en tant qu'index.
#
# Si un index était déjà défini, les données associées sont définitivement perdues : il faut les copier au préalable dans une nouvelle colonne.

# %%
df = filtre4
df["departement"] = df.index
df = df.set_index("site")
df.head()
# Out:
#              annonces   departement
# site
# LE_BON_COIN      3211       CORREZE
# LE_BON_COIN       841        CREUSE
# LE_BON_COIN      3840  HAUTE_VIENNE
# LE_BON_COIN      4597         DOUBS
# LE_BON_COIN      2951          JURA

# %% [markdown]
# On peut supprimer l'index à l'aide de la fonction **reset_index()** : les données redeviennent une colonne ordinaire.

# %%
df = df.reset_index()
df.head()
# Out:
#           site  annonces   departement
# 0  LE_BON_COIN      3211       CORREZE
# 1  LE_BON_COIN       841        CREUSE
# 2  LE_BON_COIN      3840  HAUTE_VIENNE
# 3  LE_BON_COIN      4597         DOUBS
# 4  LE_BON_COIN      2951          JURA

# %% [markdown]
# Pandas permet de définir des **index à plusieurs niveaux**, lorsqu'on passe plusieurs noms de colonnes à la fonction set_index() :

# %%
df = filtre3.reset_index()
df = df.set_index(["department","site"])
df.head(10)
# Out:
#                                           annonces
# department              site
# OISE                    A_VENDRE_A_LOUER      5129
# ARDECHE                 ANNONCES_JAUNES       2182
# ORNE                    TOP_ANNONCES          1792
# CORREZE                 LE_BON_COIN           3211
# ALPES_DE_HAUTE_PROVENCE LUX_RESIDENCE          108
# SOMME                   A_VENDRE_A_LOUER      3468
# DROME                   ANNONCES_JAUNES       3613
# SEINE_ET_MARNE          SUPER_IMMO           21536
# HAUTES_ALPES            LUX_RESIDENCE           34
# NORD                    A_VENDRE_A_LOUER     12766

# %% [markdown]
# On requête un index à deux niveaux en passant un tuple de valeurs à la propriété loc[] :

# %%
df.loc[[("ORNE","TOP_ANNONCES"),("DROME","ANNONCES_JAUNES")]]
# Out:
#                             annonces
# department site
# ORNE       TOP_ANNONCES         1792
# DROME      ANNONCES_JAUNES      3613

# %% [markdown]
# On peut trier les données d'une DataFrame avec la fonction **sort_index()** :

# %%
df = df.sort_index()
df.head(20)
# Out:
#                                  annonces
# department site
# AIN        ACHETER_LOUER             4498
#            ANNONCES_JAUNES           2516
#            A_VENDRE_A_LOUER          2533
#            BELLES_DEMEURES            116
#            BIEN_ICI                  2305
#            EXPLORIMMO                3336
#            FNAIM                      543
#            IMMONOT                    514
#            LE_BON_COIN               6518
#            LOGIC_IMMO                4908
#            LUX_RESIDENCE               91
#            PARU_VENDU                4493
#            PROPRIETES_DE_FRANCE        49
#            SE_LOGER                  6760
#            SUPER_IMMO                4653
#            TOP_ANNONCES              1854
# AISNE      ACHETER_LOUER             4239
#            ANNONCES_JAUNES           3309
#            A_VENDRE_A_LOUER          3835
#            BELLES_DEMEURES             26

# %% [markdown]
# ## Gérer les valeurs manquantes
#
# La fonction **fillna()** permet de remplir la valeur d'une cellule vide (NaN) avec la valeur de la cellule précédente (**forward filling**) ou la valeur de la cellule suivante (**backward filling**).
#
# Les fonctions statistiques ignorent les valeurs manquantes.

# %% [markdown]
# ## Fusionner des DataFrames

# %% [markdown]
# Pour les exemples qui suivent, on réutilise la table d'achats du notebook précédent :

# %%
achat1 = pd.Series({"nom":"Jean","article":"pain","prix":1.1})
achat2 = pd.Series({"nom":"Pierre","article":"lait","prix":2.5})
achat3 = pd.Series({"nom":"Marc","article":"chips","prix":1.9})
df = pd.DataFrame([achat1,achat2,achat3],index=["magasin1","magasin1","magasin2"])
df
# Out:
#          article     nom  prix
# magasin1    pain    Jean   1.1
# magasin1    lait  Pierre   2.5
# magasin2   chips    Marc   1.9

# %% [markdown]
# Voici différentes manières d'ajouter des données dans de nouvelles colonnes à cette table :

# %%
df["Date"] = ["Janvier","Février","Mars"]
df
# Out:
#          article     nom  prix     Date
# magasin1    pain    Jean   1.1  Janvier
# magasin1    lait  Pierre   2.5  Février
# magasin2   chips    Marc   1.9     Mars

# %%
df["enregistre"] = True
df
# Out:
#          article     nom  prix     Date  enregistre
# magasin1    pain    Jean   1.1  Janvier        True
# magasin1    lait  Pierre   2.5  Février        True
# magasin2   chips    Marc   1.9     Mars        True

# %%
df["Avis"] = ["Positif",None,"Négatif"]
df
# Out:
#          article     nom  prix     Date  enregistre     Avis
# magasin1    pain    Jean   1.1  Janvier        True  Positif
# magasin1    lait  Pierre   2.5  Février        True     None
# magasin2   chips    Marc   1.9     Mars        True  Négatif

# %%
rdf = df.reset_index()
rdf["Date"] = pd.Series({0:"Juin",2:"Mai"})
rdf
# Out:
#       index article     nom  prix  Date  enregistre     Avis
# 0  magasin1    pain    Jean   1.1  Juin        True  Positif
# 1  magasin1    lait  Pierre   2.5   NaN        True     None
# 2  magasin2   chips    Marc   1.9   Mai        True  Négatif

# %% [markdown]
# Pour fusionner (réaliser une jointure entre) deux DataFrames, on utilise la fonction **merge()**.
#
# Le paramètre **how** est utilisé pour spécifier le type de jointure à réaliser :
# - outer : full outer join (union)
# - inner : inner join (intersection)
# - left : left outer join
# - right : right outer join

# %%
etudiants = pd.DataFrame([{"Nom":"Jean","Année":"2017"},
                          {"Nom":"Pierre","Année":"2016"},
                          {"Nom":"Marc","Année":"2015"}])
etudiants = etudiants.set_index("Nom")

professeurs = pd.DataFrame([{"Nom":"Albert","Matière":"Physique"},
                            {"Nom":"Raymond","Matière":"Math"},
                            {"Nom":"Jean","Matière":"Math"},
                            {"Nom":"Marc","Matière":"Physique"}])
professeurs = professeurs.set_index("Nom")

# %%
dfout = pd.merge(etudiants, professeurs, how="outer", left_index=True, right_index=True)
dfout
# Out:
#         Année   Matière
# Nom
# Albert    NaN  Physique
# Jean     2017      Math
# Marc     2015  Physique
# Pierre   2016       NaN
# Raymond   NaN      Math

# %% [markdown]
# Après fusion, on note qu'on retrouve dans la DataFrame résultat l'ensemble des lignes et des colonnes des deux tables d'origine, avec des valeurs absentes (NaN) dans tous les lignes qui ne se retouvent pas dans les deux tableaux d'origine.

# %%
dfinner = pd.merge(etudiants, professeurs, how="inner", left_index=True, right_index=True)
dfinner
# Out:
#      Année   Matière
# Nom
# Jean  2017      Math
# Marc  2015  Physique

# %%
dfleft = pd.merge(etudiants, professeurs, how="left", left_index=True, right_index=True)
dfleft
# Out:
#        Année   Matière
# Nom
# Jean    2017      Math
# Pierre  2016       NaN
# Marc    2015  Physique

# %%
dfright = pd.merge(etudiants, professeurs, how="right", left_index=True, right_index=True)
dfright
# Out:
#         Année   Matière
# Nom
# Albert    NaN  Physique
# Raymond   NaN      Math
# Jean     2017      Math
# Marc     2015  Physique

# %% [markdown]
# NB : il n'est pas obligatoire d'utiliser des index pour fusionner deux DataFrames, on peut aussi utiliser des colonnes ordinaires à l'aide des paramètres **left_on** et **right_on**.

# %%
dfnoindex = pd.merge(etudiants.reset_index(), professeurs.reset_index(), 
                     how="left", left_on="Nom", right_on="Nom")
dfnoindex
# Out:
#       Nom Année   Matière
# 0    Jean  2017      Math
# 1  Pierre  2016       NaN
# 2    Marc  2015  Physique

# %% [markdown]
# Lorsque les deux tables fusionnées contiennent à l'oirigine une colonne du même nom, Pandas préserve les deux colonnes d'origine, et suffixe leur nom de _x ou _y :

# %%
etudiants["Adresse"] = ["Salle A", "Salle B", "Salle C"]
professeurs["Adresse"] = ["Salle D", "Salle E", "Salle F", "Salle G"]

dfconflict = pd.merge(etudiants, professeurs, how="left", left_index=True, right_index=True)
dfconflict
# Out:
#        Année Adresse_x   Matière Adresse_y
# Nom
# Jean    2017   Salle A      Math   Salle F
# Pierre  2016   Salle B       NaN       NaN
# Marc    2015   Salle C  Physique   Salle G

# %% [markdown]
# Pour réaliser une jointure sur plusieurs colonnes, il suffit de passer des listes de noms de colonnes dans les paramètres **left_on** et **right_on** de la fonction merge().
#
# Par exemple :
#
# pd.merge(table1, table2, left_on=["nom","prénom"], right_on=["lastName","firstName])

# %% [markdown]
# ## Conseils d'utilisation de Pandas
#
# 1. Eviter le chainage d'opérateurs d'indexation (crochets) : Pandas peut retourner une copie des données
#
# Exemple : df.loc["indexLigne"]["nomColonne"]
